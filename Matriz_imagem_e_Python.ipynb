# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt


M = Image.open("br.jpg")

# transformando para Numpy array
M = np.array(M)

# visualizando
plt.figure(figsize=(5, 5))
im = plt.imshow(M[100:500,100:300], aspect='auto')
plt.axis("off")
plt.show()

# %%
img = np.array(M)
